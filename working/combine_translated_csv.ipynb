# %%
import pandas as pd

# %%
df0 = pd.read_csv("train1-first90k.csv", index_col=None)[:90000]
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df0.head()
# Out:
#     itemid                                              title  Category  \
# 0   307504               nyx sex bomb pallete natural palette         0
# 1   461203  etude house precious mineral any cushion pearl...         1
# 2  3592295                           milani rose powder blush         2
# 3  4460167                etude house baby sweet sugar powder         3
# 4  5853995       bedak revlon color stay aqua mineral make up         3
#
#                                           image_path  \
# 0  beauty_image/6b2e9cbb279ac95703348368aa65da09.jpg
# 1  beauty_image/20450222d857c9571ba8fa23bdedc8c9.jpg
# 2  beauty_image/6a5962bed605a3dd6604ca3a4278a4f9.jpg
# 3  beauty_image/56987ae186e8a8e71fcc5a261ca485da.jpg
# 4  beauty_image/9c6968066ebab57588c2f757a240d8b9.jpg
#
#                                           Unnamed: 4
# 0               Nyx natural palette palette sex bomb
# 1  etude house precious mineral pearl cushion any...
# ...

# %%
df0.tail()
# Out:
#            itemid                                              title  \
# 89995  1688158849  missha magic cushion set free refill puff shad...
# 89996  1688730965  dior skin forever perfect cushion ori reject s...
# 89997  1688991384           wet n wild megacushion foundation spf 15
# 89998  1689753926  the balm take home bronze anti orange bronzer ...
# 89999  1690374898  bedak compak aprilskin padat basah 2in1 bentuk...
#
#        Category                                         image_path  \
# 89995         5  beauty_image/18a7adaced258732c3f9ceb62097c96a.jpg
# 89996         3  beauty_image/da5cf5be0850f16e645e950b5ccbaaad.jpg
# 89997         1  beauty_image/70e4498ca05373a7019e4765572d0452.jpg
# 89998        11  beauty_image/4bf196208ce91834b972f1cd7cf7fcd6.jpg
# 89999         3  beauty_image/7f35c063791ca9497f5066c327421087.jpg
#
#                                               Unnamed: 4
# 89995  Missha magic puff cushion set free refill shad...
# ...

# %%
# df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train1-remainder-ok.csv", index_col=None)

# %%
df1.head()
# Out:
#        itemid                                              title  Category  \
# 0  1690872732        ready sr12 exclusive compact powder natural         3
# 1  1691108371  ready stock etude zero sebum drying powder new...         3
# 2  1691196242  dijual skin bright loose powder for oily natur...         3
# 3  1691276515  ready wet n wild highlighting powder precious ...         3
# 4  1691300581  terlaris april skin magic cushion snow black v...         3
#
#                                           image_path  \
# 0  beauty_image/c30d5f446747fdd98aaa39c1045a8944.jpg
# 1  beauty_image/9bd31cc4aebc01d9df6f1d27442d53d5.jpg
# 2  beauty_image/45b9968bc43b88af3881a97c6281ebd5.jpg
# 3  beauty_image/ec944b2ed3fefd4d10dac26ba69bde3b.jpg
# 4  beauty_image/02c6f56aa631d93039490283c26ba0e9.jpg
#
#                                           Unnamed: 4
# 0        ready sr12 exclusive natural compact powder
# 1  ready stock etude sebum zero new edition of dr...
# ...

# %%
df1.tail()
# Out:
#            itemid                                              title  \
# 79994  1134517541  bedak wajah viva compact powder kuning langsat...
# 79995  1137226506  cuci gudang laneige bb cushion pore control sp...
# 79996  1137763787  terlaris kakak wardah exclusive liquid foundat...
# 79997  1137781382          nyx born to glow liquid highlighter gleam
# 79998  1138430452    fondation jafra original promo glowing cc cream
#
#        Category                                         image_path  \
# 79994         3  beauty_image/43ffe6293c0e1f39101bad43cb6e944c.jpg
# 79995         5  beauty_image/aa6bdf3c3452fb31e26a44c12e9ecd90.jpg
# 79996         1  beauty_image/bbe4a71773f9ad308d6159e1c50bb00a.jpg
# 79997         8  beauty_image/663ec4fd2540602661f615c3c329d505.jpg
# 79998         1  beauty_image/71c27a969cf680130b7dd178e6ca9701.jpg
#
#                                               Unnamed: 4
# 79994  viva face powder compact powder 19gr olive typ...
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train2-first90k.csv", index_col=None)[:90000]

# %%
df1.head()
# Out:
#        itemid                                              title  Category  \
# 0  1139906066  nyx hydra touch powder foundation natural limited         1
# 1  1142003561               termurah makeover loose powder bedak         3
# 2  1143155544                 preloved bless acne compact powder         3
# 3  1147679721  hot promo viva liquid foundation poundation 30...         1
# 4  1148926818                             cream natural 99 night         4
#
#                                           image_path  \
# 0  beauty_image/c64487b37bbb8971b4a3755fd0de16e8.jpg
# 1  beauty_image/2824b24a582a7e2f8bb7fc8f1e9488bb.jpg
# 2  beauty_image/5422943ecc280326fd27e7e5fcab76cd.jpg
# 3  beauty_image/b055813f3b1c25d6b71823a9d06a44a7.jpg
# 4  beauty_image/af6f514672ed23e5214a82eaba15d181.jpg
#
#                                           Unnamed: 4
# 0  Nyx hydra touch limited natural foundation powder
# 1                makeover lowest loose powder powder
# ...

# %%
df1.tail()
# Out:
#          itemid                                  title  Category  \
# 89995  31420355          loccitane ultra rich lip balm        12
# 89996  31687759                   cherry lip gel patch        12
# 89997  31887644  nyx soft matte lip cream original usa        12
# 89998  34637001               nyx soft matte lip cream        12
# 89999  35119588               hare hijau lipstick arab        12
#
#                                               image_path  \
# 89995  beauty_image/4ff436ff0546ed57763c475eeb60f3e5.jpg
# 89996  beauty_image/42e9939f5ed25567dd0a7e990bf524dc.jpg
# 89997  beauty_image/e4107b1ed38f70ecdec826a70039792f.jpg
# 89998  beauty_image/8fac7f2cc3357c962579c6570b282b30.jpg
# 89999  beauty_image/511bb6a9a2ba8f39c98ba9c58481a413.jpg
#
#                                   Unnamed: 4
# 89995          Loccitane ultra-rich lip balm
# 89996                   cherry lip gel patch
# 89997  Nyx soft matte lip cream original usa
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train2-remainder-ok.csv", index_col=None)

# %%
df1.head()
# Out:
#      itemid                                              title  Category  \
# 0  37686256  lipgloss kiss beauty full color 7591 warna bb ...        13
# 1  40918284                         the balm meet matte hughes        12
# 2  41210387            ysl rouge pur couture 13 le orange kiss        12
# 3  46592141                        the balm meet matt e hughes        12
# 4  48422217                         lip cream mineral botanica        12
#
#                                           image_path  \
# 0  beauty_image/6e7960c7a9b213d66e31911ecf35a614.jpg
# 1  beauty_image/952949791d148c4fc4405cd6cd58d5b5.jpg
# 2  beauty_image/8b0968fc01a42b99e95ff87cc9f7984c.jpg
# 3  beauty_image/d03fe48c0a78e22e4c3027ee36186ead.jpg
# 4  beauty_image/8ed6ae2463031e059c341dafad5cef02.jpg
#
#                                           Unnamed: 4
# 0  Kiss lipgloss beauty color 7591 mm full color ...
# 1                         the balm meet matte hughes
# ...

# %%
df1.tail()
# Out:
#            itemid                                              title  \
# 79995  1001571579                                       annabel maxy
# 79996  1001951903  sumolux dress swing pinup vintage 50s lipit ta...
# 79997  1003500837  women short sleeve hollow out waist v neck lon...
# 79998  1010359360  dress jeans denim slim casual elegan lengan pa...
# 79999  1016294527  ready stock tersedia wedding gown brokat baju ...
#
#        Category                                      image_path  \
# 79995        20  fashion_image/063e3d0b92ba56e806fd1ead1cca0bf8
# 79996        18  fashion_image/a1c3d8a99ac9fd4722acadf8c72e54cd
# 79997        18  fashion_image/03ac74d2186bf7b32193b8713c42e379
# 79998        18  fashion_image/2969e798b2ff63816e798ea132f03069
# 79999        19  fashion_image/91779516fddbdfb585f0e3f59c5157ab
#
#                                               Unnamed: 4
# 79995                                       annabel maxy
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train3-first80k.csv")[:80000]

# %%
df1.head()
# Out:
#        itemid                                              title  Category  \
# 0  1018430160  dijual biru turkish rvy1171 gaun kebaya pesta ...        24
# 1  1019541566           dress tunik lengan 3 4 motif print bunga        18
# 2  1019713675  long dress maxi model hollow bahan lace untuk ...        23
# 3  1021267384  women casual short sleeve patchwork bodycon dress        22
# 4  1021392865  lace dresses o neck backless hollow clubwear p...        19
#
#                                        image_path  \
# 0  fashion_image/8cf9f166e581163db3a8c9881b73ec49
# 1  fashion_image/45f94e7cdaf7252189af4d4a04ea344a
# 2  fashion_image/63711b1b9a90465d97917164c4888777
# 3  fashion_image/66b6abb84bf8638a4462e7d0feb906fa
# 4  fashion_image/cb88ef4e6edbe9919c39390167635461
#
#                                           Unnamed: 4
# 0  turkish blue sold graduation party rvy1171 mod...
# 1          dress tunic sleeve floral print motif 3 4
# ...

# %%
df1.tail()
# Out:
#           itemid                                              title  Category  \
# 79995  227468835                        dari blus renda bahu floral        26
# 79996  229628376  fashion wanita sweater kaos high neck lengan p...        26
# 79997  236568752     c1s crop top o neck sexy bahan lace transparan        29
# 79998  240362321  velvet room hmt108 size 20 h&m v neck longslee...        26
# 79999  255448264              blus casual lengan pendek bahan sifon        26
#
#                                            image_path  \
# 79995  fashion_image/c24a32ad2890d91b495a054e88b8e8b1
# 79996  fashion_image/2412bc396f199e83fe2c6f7f0e95f5d1
# 79997  fashion_image/d2ab40b2420ec13c2255467e60058c0b
# 79998  fashion_image/ced4ee0677b540b5e5de38d8ef2e24aa
# 79999  fashion_image/c69c43ddeb5a349c81ca133a4a0d5a27
#
#                                               Unnamed: 4
# 79995                   from shoulder floral lace blouse
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train3-remainder-ok.csv", index_col=None)

# %%
df1.head()
# Out:
#       itemid                                              title  Category  \
# 0  290440987           kemeja v neck lengan panjang model sifon        25
# 1  292411133                     kaos stripe tee lengan panjang        25
# 2  294639574     jual murah cotton stripe blouse merah dan biru        26
# 3  294978607  kaos t shirt lengan pendek bahan katun motif p...        25
# 4  313118665  fashion wanita tank top velvet v neck backless...        25
#
#                                        image_path  \
# 0  fashion_image/9d1bbcc941e5d9f9ec44ca8e8853a70b
# 1  fashion_image/99948ea3c67f022e30011c46b01021c2
# 2  fashion_image/616f94fac83f1862b844424136e2d360
# 3  fashion_image/03b36b3e4682b96c9c825166036f2bf0
# 4  fashion_image/025d98e3f30da953fe433f438aa161a2
#
#                                           Unnamed: 4
# 0            v neck long sleeve shirt chiffon models
# 1                      stripe long sleeve tee shirts
# 2    selling cheap cotton red blouse and blue stripe
# ...

# %%
df1.tail()
# Out:
#            itemid                                              title  \
# 89995  1329461526  big sale bulan juli vivo v9 ram 4 6gb rom 64 g...
# 89996  1330493108  oppo f3 black edition ram 4 gb fullset mulus i...
# 89997  1330496798                                 xiomi redmi 5 note
# 89998  1331359678          iphone 7 plus 256gb red edtion bnib inter
# 89999  1333165821  modem dt 100 lte 4g plus advance aksesoris han...
#
#        Category                                         image_path  \
# 89995        42  mobile_image/d2102cd1ff864d6f57a46e83260a493e.jpg
# 89996        35  mobile_image/3f16a31fc276dfd0e1fee6a5216e0b00.jpg
# 89997        35  mobile_image/801be0c56db15b939ff02051d7017015.jpg
# 89998        31  mobile_image/37faeef93d54182ca9e697ce7b0c8991.jpg
# 89999        45  mobile_image/5117158961087f8e38189d59477ce0fc.jpg
#
#                                               Unnamed: 4
# 89995  big sale in July vivo v9 4 6GB ram rom 64 warr...
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train4-first90k.csv", index_col=None)[:90000]

# %%
df1.head()
# Out:
#        itemid                                              title  Category  \
# 0  1333653092  big sale bulan julii sony xperia m4 global sin...        33
# 1  1333766066  samsung galaxy s6 iron man shockproof armor hy...        32
# 2  1334425343                             samsung galaxi j2prime        35
# 3  1335044135  promo cuci gudang oppo f5 6gb ram 64gb rom wa ...        35
# 4  1337012827  second iphone 6 16gb gray mulus fulset ex resm...        35
#
#                                           image_path  \
# 0  mobile_image/b0eacdf8e97dc57e64cd30cd0c55da9d.jpg
# 1  mobile_image/1431947e5c927542a0f157b9fa3c3f98.jpg
# 2  mobile_image/e7ad376d7d9249dc7667b91114665ffd.jpg
# 3  mobile_image/1c0231118cf0c3f006851167e6b11dc2.jpg
# 4  mobile_image/26e4a49f1137ae75cc3eb6b3d6694455.jpg
#
#                                           Unnamed: 4
# 0  big sale in julii sony xperia global m4 seamle...
# 1  samsung galaxy s6 shockproof armor iron man be...
# ...

# %%
df1.tail()
# Out:
#            itemid                                              title  \
# 89995  1119539777  custom case asus zenfone go b 4.5 zb452kg brow...
# 89996  1124086638  iphone 6s plus 64gb rosegold fu fullset mulus ...
# 89997  1125221393                        meizu m6 blue garansi resmi
# 89998  1125845060                 redmi 5 ram 3gb rom 32gb new murah
# 89999  1127630720  soft cct oppo f3 a77 selfie back cover like ca...
#
#        Category                                         image_path  \
# 89995        35  mobile_image/e6bb162424610763696d02d1803e8d89.jpg
# 89996        35  mobile_image/308b39d8f288bfcb2d7af7222ff90809.jpg
# 89997        35  mobile_image/3f17f09bef6018661840cdcab080973c.jpg
# 89998        34  mobile_image/15428c396a7fd9f3d6e70e35dfe75472.jpg
# 89999        41  mobile_image/826a47d5afd7e16b93a11f6df19224c9.jpg
#
#                                               Unnamed: 4
# 89995  Asus Zenfone custom case go b 4.5 zb452kg brow...
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df1 = pd.read_csv("train4-remainder-ok.csv", index_col=None)

# %%
df1.head()
# Out:
#        itemid                                              title  Category  \
# 0  1127953320  bridx carbon armor ctr xiaomi redmi 4 anti gem...        34
# 1  1130365174                             samsung galaxy a5 2015        32
# 2  1130727117  android sikur granite phone ram 2 16gb bnob be...        57
# 3  1131387873  calandiva front cct samsung note 8 6.3 inch hi...        32
# 4  1132262798  fibercarbon soft cct samsung galaxy j5 pro 201...        32
#
#                                           image_path  \
# 0  mobile_image/64c3525c21b606366eaa2e559ba1a8be.jpg
# 1  mobile_image/513975a954e701ab1be24ac93e621c66.jpg
# 2  mobile_image/886bc7d7bad97250b2421eb7a4c83eb0.jpg
# 3  mobile_image/a796f4789d8337466a6d09633f775aef.jpg
# 4  mobile_image/ce6b9a7236da15d4262a7db1d9ec6bd6.jpg
#
#                                           Unnamed: 4
# 0  bridx carbon armor ctr Xiaomi anti-earthquake ...
# 1                             samsung galaxy a5 2015
# ...

# %%
df1.tail()
# Out:
#            itemid                                              title  \
# 66611  1510771637  beli 2 gratis 1 xiaomi mi mix black 6 64 rom g...
# 66612  1515822742  android i phone x real 4g 16gb free wireless c...
# 66613  1516747666                     xiaomi mia1 ram 4gb 64gb black
# 66614  1517270941                   khusus hari ini samsung j2 prime
# 66615  1518889125            oppo a83 2 gb new garansi resmi 1 tahun
#
#        Category                                         image_path  \
# 66611        34  mobile_image/70e0d8ddd69692b0f134498efbddf4e1.jpg
# 66612        35  mobile_image/d58393fe029ba62160d2a5d1fa6638a1.jpg
# 66613        34  mobile_image/bfacb3c9af2f6a597008e57fb2d34609.jpg
# 66614        32  mobile_image/42d74ab8212a24720d42e84c649ab488.jpg
# 66615        41  mobile_image/0b10f33a67ccb4ee3e1240d44c2ee0ef.jpg
#
#                                               Unnamed: 4
# 66611  buy 2 free 1 Xiaomi mi mix black 6 64 global r...
# ...

# %%
df0 = df0.append(df1, ignore_index=True)

# %%
df0 = df0.rename(columns={'Unnamed: 4': 'title_translated'})

# %%
df0.to_csv("train.csv", index=False)

# %%
pd.read_csv("train.csv")
# Out:
#             itemid                                              title  \
# 0           307504               nyx sex bomb pallete natural palette
# 1           461203  etude house precious mineral any cushion pearl...
# 2          3592295                           milani rose powder blush
# 3          4460167                etude house baby sweet sugar powder
# 4          5853995       bedak revlon color stay aqua mineral make up
# 5          6208490                            dr pure whitening cream
# 6          6959546                         chanel powder blush malice
# 7          8984461                     snail white cream original 100
# 8          9184082                          sunprise all proof spf 50
# 9         10345338             eyebrow powder nyx satuan rp 15.000 pc
# 10        11016411                        monistat chafing relief gel
# 11        11425757                       milani rose powder blush tea
# ...

# %%
dft = pd.read_csv("test-ok.csv")

# %%
dft.head()
# Out:
#        itemid                                              title  \
# 0   370855998               flormar 7 white cream bb spf 30 40ml
# 1   637234604  maybelline clear smooth all in one bb cream sp...
# 2   690282890  murah innisfree eco natural green tea bb cream...
# 3   930913462  loreal white perfect day cream spf 17 pa white...
# 4  1039280071  hada labo cc cream ultimate anti aging spf 35 ...
#
#                                           image_path  Unnamed: 3  \
# 0  beauty_image/1588591395c5a254bab84042005f2a9f.jpg         NaN
# 1  beauty_image/920985ed9587ea20f58686ea74e20f93.jpg         NaN
# 2  beauty_image/90b40e5710f54352b243fcfb0f5d1d7f.jpg         NaN
# 3  beauty_image/289c668ef3d70e1d929d602d52d5d78a.jpg         NaN
# 4  beauty_image/d5b3e652c5822d2306f4560488ec30c6.jpg         NaN
#
#                                           Unnamed: 4
# 0               flormar 7 mm white cream spf 30 40ml
# 1  maybelline clear smooth all in one bb cream sp...
# ...

# %%
dft.tail()
# Out:
#             itemid                                              title  \
# 172397  1781957365  nokia 5.1 plus ram 3gb 32gb garansi resmi 1 ta...
# 172398  1839851276  big promo add whatshap 0821 9127 5399 iphone 7...
# 172399   955369303  datang lagi sharp r1 ram 3gb 32gb gratis silic...
# 172400  1638035772  sony xperia z5 premium au ram 3gb rom 32gb sec...
# 172401  1498091427                      xiaomi mi 8 ram 6 128gb black
#
#                                                image_path  Unnamed: 3  \
# 172397  mobile_image/3dbd99b9d999d326d8ae57f7ad1f1b3e.jpg         NaN
# 172398  mobile_image/6d45e5c7e36ac897f58a9f72ff4bf0b8.jpg         NaN
# 172399  mobile_image/08f68bb1cc3f381364776ac5cfd9e45e.jpg         NaN
# 172400  mobile_image/1d0610ea0f43d75ecc3ff951f6c647d4.jpg         NaN
# 172401  mobile_image/6649fa043a7b2eebda6ed904c966a14b.jpg         NaN
#
#                                                Unnamed: 4
# 172397  nokia 5.1 3GB of RAM plus 32GB black 1 year wa...
# ...

# %%
dft = dft.drop(['Unnamed: 3'], axis=1)

# %%
dft = dft.rename(columns={'Unnamed: 4': 'title_translated'})

# %%
dft.head()
# Out:
#        itemid                                              title  \
# 0   370855998               flormar 7 white cream bb spf 30 40ml
# 1   637234604  maybelline clear smooth all in one bb cream sp...
# 2   690282890  murah innisfree eco natural green tea bb cream...
# 3   930913462  loreal white perfect day cream spf 17 pa white...
# 4  1039280071  hada labo cc cream ultimate anti aging spf 35 ...
#
#                                           image_path  \
# 0  beauty_image/1588591395c5a254bab84042005f2a9f.jpg
# 1  beauty_image/920985ed9587ea20f58686ea74e20f93.jpg
# 2  beauty_image/90b40e5710f54352b243fcfb0f5d1d7f.jpg
# 3  beauty_image/289c668ef3d70e1d929d602d52d5d78a.jpg
# 4  beauty_image/d5b3e652c5822d2306f4560488ec30c6.jpg
#
#                                     title_translated
# 0               flormar 7 mm white cream spf 30 40ml
# 1  maybelline clear smooth all in one bb cream sp...
# 2  Innisfree's natural eco green tea pa bb cream ...
# ...

# %%
dft.tail()
# Out:
#             itemid                                              title  \
# 172397  1781957365  nokia 5.1 plus ram 3gb 32gb garansi resmi 1 ta...
# 172398  1839851276  big promo add whatshap 0821 9127 5399 iphone 7...
# 172399   955369303  datang lagi sharp r1 ram 3gb 32gb gratis silic...
# 172400  1638035772  sony xperia z5 premium au ram 3gb rom 32gb sec...
# 172401  1498091427                      xiaomi mi 8 ram 6 128gb black
#
#                                                image_path  \
# 172397  mobile_image/3dbd99b9d999d326d8ae57f7ad1f1b3e.jpg
# 172398  mobile_image/6d45e5c7e36ac897f58a9f72ff4bf0b8.jpg
# 172399  mobile_image/08f68bb1cc3f381364776ac5cfd9e45e.jpg
# 172400  mobile_image/1d0610ea0f43d75ecc3ff951f6c647d4.jpg
# 172401  mobile_image/6649fa043a7b2eebda6ed904c966a14b.jpg
#
#                                          title_translated
# 172397  nokia 5.1 3GB of RAM plus 32GB black 1 year wa...
# 172398  big promo add whatshap 0821 9127 5399 7 gold 3...
# ...

# %%
dft.to_csv("test.csv", index=False)

# %%
pd.read_csv("test.csv")
# Out:
#             itemid                                              title  \
# 0        370855998               flormar 7 white cream bb spf 30 40ml
# 1        637234604  maybelline clear smooth all in one bb cream sp...
# 2        690282890  murah innisfree eco natural green tea bb cream...
# 3        930913462  loreal white perfect day cream spf 17 pa white...
# 4       1039280071  hada labo cc cream ultimate anti aging spf 35 ...
# 5       1327710392  cathy doll cc speed white powder pact spf 40 o...
# 6       1328802799           safi white natural brightening cream 45g
# 7       1330468145  light beige 03 bioaqua bb cushion exquisite de...
# 8       1677309730  new produk missha m perfect bb cream share in ...
# 9       1683142205      ready laneige bb cushion anti aging spf 50 pa
# 10      1704308849  terupdate laneige bb cushion anti aging spf 50...
# 11      1736407742  new collection bioaqua cushion blush on smooth...
# ...
